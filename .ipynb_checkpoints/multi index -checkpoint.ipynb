# %%
import pandas as pd
import numpy as np

# Creating a more complex dataframe with multi-index
index = pd.MultiIndex.from_tuples([('New York', 'Q1', 'one'), ('New York', 'Q1', 'two'),
                                   ('Los Angeles', 'Q1', 'one'), ('Los Angeles', 'Q1', 'two'),
                                   ('Chicago', 'Q2', 'one'), ('Chicago', 'Q2', 'two'),
                                   ('New York', 'Q2', 'one'), ('New York', 'Q2', 'two')],
                                  names=['City', 'Quarter', 'ID'])

# Creating random data for Sales, Profit, and Quantity
sales = np.round(np.random.uniform(100, 500, 8), 2)  # Sales between 100 and 500
profit = np.round(np.random.uniform(0, 0.35, 8), 2)     # Profit between 0 and 0.35
quantity = np.random.randint(1, 20, 8)               # Quantity as integers

# Creating the dataframe
df_multi = pd.DataFrame({'Sales': sales, 'Profit(%)': profit, 'Quantity': quantity}, index=index)

print(df_multi)
# Out:
#                           Sales  Profit(%)  Quantity
# City        Quarter ID
# New York    Q1      one  164.94       0.21        15
#                     two  322.82       0.26        14
# Los Angeles Q1      one  195.99       0.11         9
#                     two  224.61       0.31         8
# Chicago     Q2      one  341.04       0.24         7
#                     two  400.65       0.05         6
# New York    Q2      one  458.88       0.10        18
#                     two  394.30       0.32        16

# %%
print(df_multi.loc['Chicago', 'Sales'])
# Out:
# Quarter  ID
# Q2       one    341.04
#          two    400.65
# Name: Sales, dtype: float64
# C:\Users\DELL\AppData\Local\Temp\ipykernel_9448\3604561633.py:1: PerformanceWarning: indexing past lexsort depth may impact performance.
#   print(df_multi.loc['Chicago', 'Sales'])

# %%
print(df_multi.loc[('New York', 'Q2'),'Profit(%)'])
# Out:
# ID
# one    0.10
# two    0.32
# Name: Profit(%), dtype: float64
# C:\Users\DELL\AppData\Local\Temp\ipykernel_9448\2219958533.py:1: PerformanceWarning: indexing past lexsort depth may impact performance.
#   print(df_multi.loc[('New York', 'Q2'),'Profit(%)'])

# %%
print(df_multi.loc[(['New York', 'Chicago'], 'Q2'), 'Profit(%)'])
# Out:
# City      Quarter  ID
# New York  Q2       one    0.10
#                    two    0.32
# Chicago   Q2       one    0.24
#                    two    0.05
# Name: Profit(%), dtype: float64

# %%
print(df_multi.loc[(['New York', 'Chicago'], 'Q2'), ['Profit(%)','Quantity']])
# Out:
#                       Profit(%)  Quantity
# City     Quarter ID
# New York Q2      one       0.10        18
#                  two       0.32        16
# Chicago  Q2      one       0.24         7
#                  two       0.05         6

# %%
print(df_multi.loc[('Chicago', 'Q2'),'Sales'])
# Out:
# ID
# one    341.04
# two    400.65
# Name: Sales, dtype: float64
# C:\Users\DELL\AppData\Local\Temp\ipykernel_9448\2276367391.py:1: PerformanceWarning: indexing past lexsort depth may impact performance.
#   print(df_multi.loc[('Chicago', 'Q2'),'Sales']).reset_index()
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 print(df_multi.loc[('Chicago', 'Q2'),'Sales']).reset_index()
#
# AttributeError: 'NoneType' object has no attribute 'reset_index'

# %%
print(df_multi.loc[(slice(None),slice(None),"one"),:])
# Out:
#                           Sales  Profit(%)  Quantity
# City        Quarter ID
# New York    Q1      one  164.94       0.21        15
# Los Angeles Q1      one  195.99       0.11         9
# Chicago     Q2      one  341.04       0.24         7
# New York    Q2      one  458.88       0.10        18

# %%
print(df_multi.loc[(slice(None),"Q1",slice(None)),:])
# Out:
#                           Sales  Profit(%)  Quantity
# City        Quarter ID
# New York    Q1      one  164.94       0.21        15
#                     two  322.82       0.26        14
# Los Angeles Q1      one  195.99       0.11         9
#                     two  224.61       0.31         8

# %%
print(df_multi[df_multi['Sales'] > 200])
# Out:
#                           Sales  Profit(%)  Quantity
# City        Quarter ID
# New York    Q1      two  322.82       0.26        14
# Los Angeles Q1      two  224.61       0.31         8
# Chicago     Q2      one  341.04       0.24         7
#                     two  400.65       0.05         6
# New York    Q2      one  458.88       0.10        18
#                     two  394.30       0.32        16

# %%
print(df_multi[df_multi['Quantity'] > 10]['Quantity'])
# Out:
# City      Quarter  ID
# New York  Q1       one    15
#                    two    14
#           Q2       one    18
#                    two    16
# Name: Quantity, dtype: int32

# %%
print(df_multi[df_multi['Quantity'] > 10][['Quantity','Profit(%)']])
# Out:
#                       Quantity  Profit(%)
# City     Quarter ID
# New York Q1      one        15       0.21
#                  two        14       0.26
#          Q2      one        18       0.10
#                  two        16       0.32

# %%
df_multi["Sales"].idxmax()
# Out:
# ('New York', 'Q2', 'one')

# %%
df_multi[df_multi["Profit(%)"]>0.2]
# Out:
#                           Sales  Profit(%)  Quantity
# City        Quarter ID
# New York    Q1      one  164.94       0.21        15
#                     two  322.82       0.26        14
# Los Angeles Q1      two  224.61       0.31         8
# Chicago     Q2      one  341.04       0.24         7
# New York    Q2      two  394.30       0.32        16

# %%
df_multi.groupby("City")['Sales'].mean()
# Out:
# City
# Chicago        370.845
# Los Angeles    210.300
# New York       335.235
# Name: Sales, dtype: float64

# %%
df_multi.groupby("Quarter").size()
# Out:
# Quarter
# Q1    4
# Q2    4
# dtype: int64

# %%
df_multi.loc[(slice(None),slice(None))].shape
# Out:
# (8, 3)

# %%
df_multi.groupby("Quarter").count()
# Out:
#          Sales  Profit(%)  Quantity
# Quarter
# Q1           4          4         4
# Q2           4          4         4

# %%
df_multi.index.get_level_values("Quarter").value_counts()
# Out:
# Quarter
# Q1    4
# Q2    4
# Name: count, dtype: int64
