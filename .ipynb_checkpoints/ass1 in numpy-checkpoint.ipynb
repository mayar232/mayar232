# %%
import numpy as np

# %%
#columns = [age, heart_rate, cholesterol, blood_pressure]
patients_data = np.array([
[45, 80, 200, 120],
[60, 90, 240, 140],
[30, 70, 180, 110],
[50, 85, 220, 130],
[65, 95, 260, 150]])

# %%
patients_data.shape
# Out:
# (5, 4)

# %%
pation=patients_data.shape[0]
pation
# Out:
# 5

# %%
pation=patients_data.shape[1]
pation
# Out:
# 4

# %%
patients_data[0]
# Out:
# array([ 45,  80, 200, 120])

# %%
patients_data[:,0]       #note# all row and colum0
# Out:
# array([45, 60, 30, 50, 65])

# %%
patients_data[:,3]
# Out:
# array([120, 140, 110, 130, 150])

# %%
age=patients_data[:,0]       
age.mean()
# Out:
# np.float64(50.0)

# %%
heart=patients_data[:,1]
heart.max()
# Out:
# np.int64(95)

# %%
cholesterol=patients_data[:,2]
cholesterol.min()
# Out:
# np.int64(180)

# %%
np.where(patients_data[:,3]>130)
# Out:
# (array([1, 4]),)

# %%
cholesterol=patients_data[:, 2] >= 240
cholesterol
# Out:
# array([False,  True, False, False,  True])

# %%
np. where(patients_data[:, 2] >= 240)
# Out:
# (array([1, 4]),)

# %%
np.where(patients_data[:, 0] > 50)
# Out:
# (array([1, 4]),)

# %%
highBp = patients_data[:, 3] > 140
highch = patients_data[:, 2] > 240
print(highBp,highch)
# Out:
# [False False False False  True] [False False False False  True]

# %%
patients_data[(patients_data[:, 3] > 140) | (patients_data[:, 2] > 240)]# another way
# Out:
# array([[ 65,  95, 260, 150]])

# %%
ages = patients_data[:, 0]
under_50 = patients_data[ages < 50]
above_50 = patients_data[ages >= 50]
avg_under_50 = under_50[:, 1].mean()
avg_above_50 = above_50[:, 1].mean()

avg_under_50, avg_above_50###Older patients  have a higher average heart rate
# Out:
# (np.float64(75.0), np.float64(90.0))

# %%
under_50.mean()
# Out:
# np.float64(104.375)

# %%
patients_data[patients_data[:, 3].argmax()]
# Out:
# array([ 65,  95, 260, 150])

# %%
patients_data[patients_data[:, 1].argmin()]
# Out:
# array([ 30,  70, 180, 110])

# %%
ages = patients_data[:, 0]
bp = patients_data[:, 3]

# %%
bp_under_50 = bp[ages < 50].mean()
bp_50_above = bp[ages >= 50].mean()
bp_under_50, bp_50_above
# Out:
# (np.float64(115.0), np.float64(140.0))
